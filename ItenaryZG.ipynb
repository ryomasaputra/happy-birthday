# %% [markdown]
# <a href="https://colab.research.google.com/github/ryomasaputra/happy-birthday/blob/master/ItenaryZG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Combine all the itineraries into one DataFrame
full_itinerary_data = {
    'Date and Day': [
        'June 14th, Friday', '', '', '', '', '', '',
        'June 15th, Saturday', '', '', '', '',
        'June 16th, Sunday and June 17th, Monday',
        'June 18th, Tuesday', '', '', ''
    ],
    'Time': [
        '10:50', '13:30', '15:30', '19:40', '20:25', '21:25', '21:40',
        '06:00', '08:00', '08:30', '10:08', '18:23',
        '-',
        '11:00', '13:25', '18:15', '23:30'
    ],
    'Location': [
        'Departure: Denpasar Bali (DPS)',
        'Layover: Singapore (SIN) Changi T1',
        'Departure: Singapore (SIN) Changi T3',
        'Arrival: Hong Kong (HKG)',
        'Airport Train Station',
        'Hotel',
        'Leave Hotel',
        'Breakfast Near Hotel',
        'Check Out Hotel',
        'West Kowloon Station',
        'HongKong West Kowloon',
        'Chengdu East Station',
        'Places of Interest: Chengdu Research Base of Giant Panda Breeding, Taikoo Li, People\'s Park, Kuan Alley and Zhai Alley, SKP Chengdu, Dujiangyan',
        'Chengdu Tianfu International Airport (TFU)',
        'Guangzhou Baiyun International Airport, Terminal 2',
        'Guangzhou Baiyun International Airport, Terminal 2',
        'Denpasar Bali Ngurah Rai Airport (DPS)'
    ],
    'Note': [
        'Flight SQ 8601 with Scoot, Aircraft Boeing 787-8',
        'Layover Duration: 2 hours',
        'Flight SQ 896 with Singapore Airlines, Aircraft Airbus A350-900',
        'Arrival at Hong Kong International Airport Terminal 1',
        'Post-arrival transit to MRT',
        'Use MRT to Tsim Sha Tsui (尖沙咀) and arrive at hotel; Hotel Paris Guesthouse - Tsim Sha Tsui Mansion',
        'Dinner and take pictures in Victoria Bay, then sleep to rest',
        'Breakfast',
        'Check out',
        'Arrive at station; buy food and amenities at minimarket',
        'HSR G2964, arrive at least 90 minutes before departure',
        'Arrival',
        '',
        'Departure on China Southern Airlines CZ3404, Boeing 737-8',
        'Transit, 4h50m layover',
        'Departure on China Southern Airlines CZ625, Airbus A321neo',
        'Arrival'
    ],
    'Price': [
        'IDR 2,390,600, total IDR 11,953,000', '', '', '', '', 'IDR 500,000 - 1,000,000', '',
        '', '', '', 'CNY 875 (IDR 1,925,000) per person, total IDR 9,625,000 for five people', '',
        '',
        'IDR 3,320,200 per person, total IDR 16,601,000 for five people', '', '', ''
    ]
}

# Creating the DataFrame
full_itinerary_df = pd.DataFrame(full_itinerary_data)

# Here is the code to print the DataFrame in a table format
print(full_itinerary_df.to_string(index=False))
# Out:
#                            Date and Day  Time                                                                                                                                        Location                                                                                               Note                                                                   Price
#                       June 14th, Friday 10:50                                                                                                                  Departure: Denpasar Bali (DPS)                                                   Flight SQ 8601 with Scoot, Aircraft Boeing 787-8                                     IDR 2,390,600, total IDR 11,953,000
# ...

# %%
def highlight_alternate_rows(s):
    return ['background-color: black; color: white' if i % 2 else 'background-color: white' for i in range(len(s))]

# Apply the style
styled_df = full_itinerary_df.style.apply(highlight_alternate_rows, axis=0)
styled_df


from IPython.display import display, HTML

display(HTML(full_itinerary_df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date and Day</th>
#       <th>Time</th>
#       <th>Location</th>
#       <th>Note</th>
#       <th>Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>June 14th, Friday</td>
#       <td>10:50</td>
#       <td>Departure: Denpasar Bali (DPS)</td>
#       <td>Flight SQ 8601 with Scoot, Aircraft Boeing 787-8</td>
#       <td>IDR 2,390,600, total IDR 11,953,000</td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>13:30</td>
#       <td>Layover: Singapore (SIN) Changi T1</td>
#       <td>Layover Duration: 2 hours</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>15:30</td>
#       <td>Departure: Singapore (SIN) Changi T3</td>
#       <td>Flight SQ 896 with Singapore Airlines, Aircraft Airbus A350-900</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td></td>
#       <td>19:40</td>
#       <td>Arrival: Hong Kong (HKG)</td>
# ...
